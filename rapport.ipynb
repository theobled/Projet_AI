# %% [markdown]
# <span style="color:red;">Final Report Structure (70%)</span>
#
#  For Option A: “A Survey of AI Techniques for LLM Optimization”
# # Introduction:
#  • Why is your chosen facet of LLM optimization a critical problem?
#  • What are the key challenges specific to this area?
# # Application of AI Techniques in your Chosen Area:
#  • A comprehensive review of the 4-8 key papers you read, organized by sub-problem or AI
#  technique.
#  • For each, explain the problem, the chosen AI method, and the outcome.
# # Implementation of a Selected Technique:
#  • Describe the specific sub-problem you chose to address.
#  • Explain the technique you implemented and justify why it is a suitable choice for this sub
# problem.
# # Empirical Evaluation:
#  • Describe your experimental setup and the results of your implementation.
#  • Go beyond reporting: critically analyze and justify the findings, identify underlying causes,
#  state assumptions, discuss limitations, and articulate trade-offs.
# # Conclusion:
#  • What are the main trends in using AI for your chosen area of LLM optimization?
#  • What have you learned from this survey and implementation?
#  • What future research do you recommend?
